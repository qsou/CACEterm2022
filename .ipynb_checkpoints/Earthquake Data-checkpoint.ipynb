# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.stats import norm
import reverse_geocoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-54ff681c5e46> in <module>
#       4 from scipy import stats
#       5 from scipy.stats import norm
# ----> 6 import reverse_geocoder
#
# ModuleNotFoundError: No module named 'reverse_geocoder'

# %%
#import and read cav file
data = pd.read_csv('all_month.csv')
# look at the top of the data
data.head()
# Out:
#                        time   latitude   longitude      depth   mag magType  \
# 0  2021-02-11T17:55:22.563Z  63.134200 -151.509700   0.000000  2.30      ml
# 1  2021-02-11T17:54:28.390Z  19.188168 -155.461670  34.619999  1.90      md
# 2  2021-02-11T17:41:05.500Z  36.067500 -117.882000   1.610000  0.86      ml
# 3  2021-02-11T17:32:20.400Z  38.824501 -122.856003   1.940000  1.34      md
# 4  2021-02-11T17:28:04.060Z  17.939800  -66.949100   6.000000  1.49      md
#
#     nst    gap      dmin   rms  ...                   updated  \
# 0   NaN    NaN       NaN  0.90  ...  2021-02-11T18:06:20.095Z
# 1  39.0  148.0       NaN  0.13  ...  2021-02-11T17:58:04.870Z
# 2   9.0  196.0  0.054600  0.07  ...  2021-02-11T17:44:44.723Z
# 3  30.0   84.0  0.003115  0.03  ...  2021-02-11T17:57:07.561Z
# 4   4.0  285.0  0.099600  0.03  ...  2021-02-11T17:55:05.369Z
#
#                                        place        type horizontalError  \
# 0  46 km SSE of Denali National Park, Alaska  earthquake             NaN
# 1                  2 km SE of Pāhala, Hawaii  earthquake            0.63
# 2               6km ENE of Coso Junction, CA  earthquake            0.30
# 3                10km WNW of The Geysers, CA  earthquake            0.22
# 4                         Puerto Rico region  earthquake            0.57
#
#   depthError  magError  magNst     status  locationSource magSource
# 0       0.20       NaN     NaN  automatic              ak        ak
# 1       0.75     1.840    10.0  automatic              hv        hv
# 2       0.22     0.176    10.0  automatic              ci        ci
# 3       0.34     0.050     6.0  automatic              nc        nc
# 4       1.43     0.050     3.0   reviewed              pr        pr
#
# [5 rows x 22 columns]

# %%
#looking at the tail of the data
data.tail()
# Out:
#                            time   latitude   longitude  depth   mag magType  \
# 10823  2021-01-12T18:40:38.818Z  38.049000 -118.774300   8.20  1.50      ml
# 10824  2021-01-12T18:38:47.600Z  39.432000 -110.327667  -1.21  1.34      md
# 10825  2021-01-12T18:28:47.411Z  60.546900 -152.096700  84.50  1.40      ml
# 10826  2021-01-12T18:24:22.430Z  32.752167 -115.826833   8.47  1.06      ml
# 10827  2021-01-12T18:17:36.605Z  -3.062900  136.877700  28.29  5.80     mww
#
#         nst    gap      dmin    rms  ...                   updated  \
# 10823  22.0  100.5  0.293000  0.134  ...  2021-01-13T02:31:24.967Z
# 10824   5.0  148.0  0.008136  0.050  ...  2021-01-12T20:24:46.440Z
# 10825   NaN    NaN       NaN  0.370  ...  2021-01-26T05:31:28.383Z
# 10826  18.0  100.0  0.128400  0.110  ...  2021-01-13T18:19:40.081Z
# 10827   NaN   14.0  3.860000  0.730  ...  2021-02-09T18:26:21.605Z
#
#                                      place        type horizontalError  \
# 10823  32 km ENE of Lee Vining, California  earthquake             NaN
# 10824         14 km SSE of Sunnyside, Utah  earthquake            1.03
# 10825         43 km W of Salamatof, Alaska  earthquake             NaN
# 10826               16km E of Ocotillo, CA  earthquake            0.20
# 10827                     Papua, Indonesia  earthquake            6.50
#
#       depthError  magError  magNst    status  locationSource magSource
# 10823       2.60     0.240     7.0  reviewed              nn        nn
# 10824       0.34     0.105     5.0  reviewed              uu        uu
# 10825       0.70       NaN     NaN  reviewed              ak        ak
# 10826       0.74     0.140     6.0  reviewed              ci        ci
# 10827       3.30     0.073    18.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
#looking at the information of the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10828 entries, 0 to 10827
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             10828 non-null  object
#  1   latitude         10828 non-null  float64
#  2   longitude        10828 non-null  float64
#  3   depth            10828 non-null  float64
#  4   mag              10827 non-null  float64
#  5   magType          10827 non-null  object
#  6   nst              7337 non-null   float64
#  7   gap              8468 non-null   float64
#  8   dmin             7512 non-null   float64
#  9   rms              10827 non-null  float64
#  10  net              10828 non-null  object
#  11  id               10828 non-null  object
#  12  updated          10828 non-null  object
#  13  place            10828 non-null  object
#  14  type             10828 non-null  object
#  15  horizontalError  7310 non-null   float64
#  16  depthError       10828 non-null  float64
#  17  magError         7717 non-null   float64
#  18  magNst           8078 non-null   float64
#  19  status           10828 non-null  object
#  20  locationSource   10828 non-null  object
#  21  magSource        10828 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 1.8+ MB

# %%
#changing the time of the data to year-month-date
data['time'] =pd.DatetimeIndex(data['time']).date

# %%
#sorting by datetime and from most current to least current
df = data.sort_values(by='time', ascending=False)
df
# Out:
#              time   latitude   longitude  depth   mag magType   nst    gap  \
# 0      2021-02-11  63.134200 -151.509700   0.00  2.30      ml   NaN    NaN
# 129    2021-02-11 -22.440500  170.944900  10.00  4.80      mb   NaN  107.0
# 120    2021-02-11  38.819000 -122.766670   2.15  0.15      md   8.0  106.0
# 121    2021-02-11  38.809166 -122.789001   2.95  1.02      md  23.0   31.0
# 122    2021-02-11  35.605333 -117.488167   6.35  1.00      ml  12.0  149.0
# ...           ...        ...         ...    ...   ...     ...   ...    ...
# 10773  2021-01-12  60.040667 -153.111667   0.82 -0.54      ml   4.0  153.0
# 10772  2021-01-12  60.049500 -153.118333   2.21 -0.94      ml   4.0  170.0
# 10771  2021-01-12  38.836000 -122.808000   1.62  0.49      md  33.0   51.0
# 10770  2021-01-12  60.087700 -153.173200   4.80  0.70      ml   NaN    NaN
# 10827  2021-01-12  -3.062900  136.877700  28.29  5.80     mww   NaN   14.0
#
#            dmin   rms  ...                   updated  \
# 0           NaN  0.90  ...  2021-02-11T18:06:20.095Z
# 129    8.149000  0.81  ...  2021-02-11T05:41:00.040Z
# 120    0.011730  0.01  ...  2021-02-11T06:32:04.607Z
# 121    0.005067  0.02  ...  2021-02-11T06:20:05.543Z
# 122    0.028300  0.15  ...  2021-02-11T05:59:26.744Z
# ...         ...   ...  ...                       ...
# 10773       NaN  0.06  ...  2021-01-13T02:56:16.290Z
# 10772       NaN  0.08  ...  2021-01-13T03:00:19.520Z
# 10771  0.012690  0.04  ...  2021-01-20T03:07:07.811Z
# 10770       NaN  0.47  ...  2021-01-26T05:31:31.686Z
# 10827  3.860000  0.73  ...  2021-02-09T18:26:21.605Z
#
#                                            place        type horizontalError  \
# 0      46 km SSE of Denali National Park, Alaska  earthquake             NaN
# 129             southeast of the Loyalty Islands  earthquake            6.80
# 120                            4km W of Cobb, CA  earthquake            0.40
# 121                    4km NW of The Geysers, CA  earthquake            0.25
# 122                     17km E of Ridgecrest, CA  earthquake            0.47
# ...                                          ...         ...             ...
# 10773             62 km ENE of Pedro Bay, Alaska  earthquake            0.31
# 10772             62 km ENE of Pedro Bay, Alaska  earthquake            0.63
# 10771                        8km WNW of Cobb, CA  earthquake            0.17
# 10770             61 km ENE of Pedro Bay, Alaska  earthquake             NaN
# 10827                           Papua, Indonesia  earthquake            6.50
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           0.20       NaN     NaN  automatic              ak        ak
# 129         1.80  0.102000    30.0   reviewed              us        us
# 120         1.08  0.080000     2.0  automatic              nc        nc
# 121         0.47  0.170000     4.0  automatic              nc        nc
# 122         0.70  0.090000    10.0  automatic              ci        ci
# ...          ...       ...     ...        ...             ...       ...
# 10773       0.39  0.198613     3.0   reviewed              av        av
# 10772       1.18  0.119753     3.0   reviewed              av        av
# 10771       0.27  0.315000     5.0   reviewed              nc        nc
# 10770       0.80       NaN     NaN   reviewed              ak        ak
# 10827       3.30  0.073000    18.0   reviewed              us        us
#
# [10828 rows x 22 columns]

# %%
#looking at all of the stats of the whole data without any filtering
df.describe()
# Out:
#            latitude     longitude         depth           mag          nst  \
# count  10828.000000  10828.000000  10828.000000  10827.000000  7337.000000
# mean      38.181062   -113.004644     22.254684      1.664963    21.976830
# std       19.334327     61.602443     49.948975      1.184936    16.163812
# min      -62.387900   -179.955500     -4.700000     -1.310000     2.000000
# 25%       33.488583   -149.772400      4.280000      0.900000    10.000000
# 50%       38.146600   -118.854500      8.450000      1.410000    18.000000
# 75%       51.865208   -115.721750     16.730000      2.070000    28.000000
# max       85.081800    179.649100    644.900000      7.700000   199.000000
#
#                gap         dmin           rms  horizontalError    depthError  \
# count  8468.000000  7512.000000  10827.000000      7310.000000  10828.000000
# mean    117.367593     0.573722      0.285331         1.634787      2.775227
# std      64.995824     2.184867      0.270946         2.954782     49.001211
# min      11.000000     0.000000      0.000000         0.090000      0.000000
# 25%      70.000000     0.023110      0.100000         0.260000      0.410000
# 50%     101.000000     0.065755      0.180000         0.450000      0.700000
# 75%     149.000000     0.186000      0.420000         0.840000      1.510000
# max     351.550000    52.111000      2.760000        23.200000   5041.100000
#
#           magError       magNst
# count  7717.000000  8078.000000
# mean      0.236839    15.561525
# std       0.373911    25.605368
# min       0.000000     0.000000
# 25%       0.108000     5.000000
# 50%       0.163000     9.000000
# 75%       0.230000    18.000000
# max       5.920000   515.000000

# %%
#all of the different columns in the dataset
df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
ml = df[df["magType"]=="ml"] #looking for all the ml in the list

# %%
ml['mag'].mean() #avg of mag with all magType of ml
# Out:
# 1.364737683476239

# %%
#all of the stats that magType is ml
ml.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  6881.000000  6881.000000  6881.000000  6881.000000  4325.000000
# mean     46.025911  -130.831612    18.458183     1.364738    22.561156
# std      12.595242    22.075569    27.552971     0.732066    17.205827
# min     -24.132200  -179.532900    -4.700000    -1.310000     2.000000
# 25%      35.607667  -150.919500     5.000000     0.900000    11.000000
# 50%      43.708500  -118.099333     8.400000     1.330000    18.000000
# 75%      60.040800  -116.501500    15.260000     1.800000    28.000000
# max      69.867700   178.976100   239.000000     5.400000   145.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  4522.000000  4090.000000  6881.000000      3365.000000  6881.000000
# mean    108.608752     0.110494     0.299090         0.637809     2.755780
# std      58.021042     0.194008     0.229845         1.121705    61.350005
# min      11.000000     0.000000     0.000300         0.090000     0.000000
# 25%      68.000000     0.031000     0.130000         0.230000     0.370000
# 50%      93.000000     0.062695     0.210000         0.340000     0.600000
# 75%     138.757500     0.122394     0.430000         0.560000     1.120000
# max     351.550000     3.067000     2.760000        13.300000  5041.100000
#
#           magError       magNst
# count  4098.000000  4134.000000
# mean      0.220913    13.705128
# std       0.387949    15.540240
# min       0.000000     0.000000
# 25%       0.121000     5.000000
# 50%       0.171000     9.000000
# 75%       0.230000    17.000000
# max       5.920000   247.000000

# %%
#Find the date and location of the largest earthquake
maxquake = df[df['mag'] == np.max(df['mag'], axis=0)]

print(maxquake['time'])

#lat and long of the maxquake

maxlat = maxquake['latitude'].to_numpy()
maxlong = maxquake['longitude'].to_numpy()
coordinates = (maxlat[0], maxlong[0])

location = reverse_geocoder.search(coordinates)
dflocation = pd.Dataframe(location)

print(dflocation['cc'])
# Out:
# 340    2021-02-10
# Name: time, dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9cd60643f2ab> in <module>
#      10 coordinates = (maxlat[0], maxlong[0])
#      11
# ---> 12 location = reverse_geocoder.search(coordinates)
#      13 dflocation = pd.Dataframe(location)
#      14
#
# NameError: name 'reverse_geocoder' is not defined

# %%
greaterthan = df[df["mag"] >= 4.5]

# %%
sns.distplot(greaterthan['mag'], fit=norm, bins=50, kde=False);
fig = plt.figure()
res = stats.probplot(greaterthan['mag'], plot=plt)
