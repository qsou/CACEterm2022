# %% [markdown]
# For this project, We are supposed to find the best car to sell to a customer based on many factors. First, I imported all of the necessary packages into this Jupyter notebook.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Here is where I read in the data sets and stored them into pandas dataframes.

# %%
cars1 = pd.read_csv('cars1.csv')

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars2 = pd.read_csv('cars2.csv')

# %%
cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
# Here is where I remove all of the unnamed columns, which would allow all the columns from data one and two to match.

# %%
cars1 = cars1.loc[:, ~cars1.columns.str.contains('^Unnamed')]

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# Here is were I made the two dataframes into one.

# %%
cars = pd.concat([cars1, cars2], axis=0)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 31.1+ KB

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %% [markdown]
# Here is where I drop all of the rows that contain all '?', which was necessary as it could not be turned into an integer.

# %%
#has to drop all of the '?' to get the max horsepower
bestcars = cars[cars.horsepower != "?"]

# %%
bestcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    int64
#  3   horsepower    392 non-null    object
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model         392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car           392 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# Here is where I changed the 'horsepower' column into an integer.

# %%
#df["a"] = pd.to_numeric(df["a"])
#horsepower was an obj and needs to be changed into int to find max
bestcars["horsepower"] = pd.to_numeric(bestcars["horsepower"])
# Out:
# <ipython-input-13-ed03a0ca9d35>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bestcars["horsepower"] = pd.to_numeric(bestcars["horsepower"])

# %% [markdown]
# Here was where I looked at each column to see if there are any correlations between each other.

# %%
bestcars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805134   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805134   0.950823      1.000000    0.897259  0.932993
# horsepower   -0.778427   0.842983      0.897259    1.000000  0.864538
# weight       -0.832244   0.897527      0.932993    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model         0.580541  -0.345647     -0.369873   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614551   -0.455171 -0.585005
#
#               acceleration     model    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369873 -0.614551
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %% [markdown]
# Here are all of the descriptive statistics from the original dataset with the rows containing "?" deleted.

# %%
bestcars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.413265  104.469388  2977.584184
# std      7.805007    1.705783    104.642823   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration       model      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# Plotted all statistical data into each histogram.

# %%
plt.hist(bestcars['mpg'],alpha=0.5);

# %%
plt.hist(bestcars['cylinders'],alpha=0.5)
# Out:
# (array([  4.,   0., 199.,   0.,   3.,   0.,  83.,   0.,   0., 103.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bestcars['displacement'],alpha=0.5)
# Out:
# (array([104.,  88.,  30.,  12.,  57.,   3.,  42.,  31.,  16.,   9.]),
#  array([ 68. , 106.7, 145.4, 184.1, 222.8, 261.5, 300.2, 338.9, 377.6,
#         416.3, 455. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bestcars['horsepower'],alpha=0.5)
# Out:
# (array([ 27.,  95., 120.,  44.,  19.,  47.,  13.,  14.,   5.,   8.]),
#  array([ 46. ,  64.4,  82.8, 101.2, 119.6, 138. , 156.4, 174.8, 193.2,
#         211.6, 230. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bestcars['weight'],alpha=0.5)
# Out:
# (array([30., 89., 58., 52., 36., 40., 29., 34., 18.,  6.]),
#  array([1613. , 1965.7, 2318.4, 2671.1, 3023.8, 3376.5, 3729.2, 4081.9,
#         4434.6, 4787.3, 5140. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bestcars['acceleration'],alpha=0.5)
# Out:
# (array([ 6., 15., 50., 85., 91., 78., 44., 12.,  7.,  4.]),
#  array([ 8.  ,  9.68, 11.36, 13.04, 14.72, 16.4 , 18.08, 19.76, 21.44,
#         23.12, 24.8 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bestcars['model'],alpha=0.5)
# Out:
# (array([56., 28., 40., 26., 30., 62., 36., 29., 27., 58.]),
#  array([70. , 71.2, 72.4, 73.6, 74.8, 76. , 77.2, 78.4, 79.6, 80.8, 82. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Here I took top 25 percent of the cars with the best mpg, since I am going toward an everyday approach. I wanted to recommend an everyday car, which mpg is our main concern as it depicts how much money we spend on gas. An everyday car to me is an car that is confortable to drive and has a good mpg, in addition with it being safe.

# %%
fc = bestcars[bestcars.mpg > 29]

# %%
fc
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 51   30.0          4            79          70    2074          19.5     71
# 52   30.0          4            88          76    2065          14.5     71
# 53   31.0          4            71          65    1773          19.0     71
# 54   35.0          4            72          69    1613          18.0     71
# 129  31.0          4            79          67    1950          19.0     74
# ..    ...        ...           ...         ...     ...           ...    ...
# 192  32.0          4           144          96    2665          13.9     82
# 193  36.0          4           135          84    2370          13.0     82
# 196  44.0          4            97          52    2130          24.6     82
# 197  32.0          4           135          84    2295          11.6     82
# 199  31.0          4           119          82    2720          19.4     82
#
#      origin                  car
# ...

# %% [markdown]
# After looking at the descriptive statistics from the original dataset, I noticed that there is some correlation between cylinders, displacement, horsepower, and weight. Then I looked at how many counts of each type of cylinder there is; since the is a positive correlation between cylinders and some of the other columns.

# %%
fc['cylinders'].value_counts()
# Out:
# 4    91
# 6     3
# 5     1
# Name: cylinders, dtype: int64

# %% [markdown]
# Here are the descriptive statistics from the top 25 percent of the cars with the best mpg.

# %%
fc.describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  95.000000  95.000000     95.000000   95.000000    95.000000
# mean   34.308421   4.073684    101.789474   70.747368  2157.957895
# std     3.865881   0.364432     25.004210   12.198682   317.177241
# min    29.500000   4.000000     71.000000   48.000000  1613.000000
# 25%    31.400000   4.000000     89.000000   65.000000  1975.000000
# 50%    33.500000   4.000000     97.000000   68.000000  2085.000000
# 75%    36.100000   4.000000    107.500000   75.000000  2255.000000
# max    46.600000   6.000000    262.000000  132.000000  3250.000000
#
#        acceleration      model     origin
# count     95.000000  95.000000  95.000000
# mean      16.650526  79.178947   2.263158
# std        2.483857   2.771354   0.840599
# min       11.400000  71.000000   1.000000
# 25%       14.850000  78.000000   1.500000
# 50%       16.400000  80.000000   3.000000
# 75%       18.100000  81.000000   3.000000
# ...

# %% [markdown]
# For the final dataset, I only placed cars with the top 25 percent of acceleration, and the reasoning behind this act is for safety. I have noticed that in an emergency if a car could get an extra boost quickly, you can avoid car crashes in most cases. There were many cases on the road that an extra boost helped people avoid car crashes.

# %%
#dfObj[(dfObj['Sale'] > 30) & (dfObj['Sale'] < 33) ]
final = fc[fc['acceleration'] >= 18.1]

# %%
final
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 51   30.0          4            79          70    2074          19.5     71
# 53   31.0          4            71          65    1773          19.0     71
# 129  31.0          4            79          67    1950          19.0     74
# 131  32.0          4            71          65    1836          21.0     74
# 145  32.0          4            83          61    2003          19.0     74
# 18   31.5          4            98          68    2045          18.5     77
# 20   36.0          4            79          58    1825          18.6     77
# 46   43.1          4            90          48    1985          21.5     78
# 48   32.8          4            78          52    1985          19.4     78
# 49   39.4          4            85          70    2070          18.6     78
# 105  31.8          4            85          65    2020          19.2     79
# ...

# %% [markdown]
# Here are the final descriptive statistics.

# %%
final.describe()
# Out:
#              mpg  cylinders  displacement  horsepower      weight  \
# count  24.000000  24.000000     24.000000   24.000000    24.00000
# mean   35.200000   4.125000     94.750000   63.583333  2220.37500
# std     5.002869   0.448427     20.724382    8.890232   416.32949
# min    29.900000   4.000000     71.000000   48.000000  1773.00000
# 25%    31.000000   4.000000     82.000000   59.500000  1982.50000
# 50%    32.400000   4.000000     89.500000   65.000000  2057.50000
# 75%    38.425000   4.000000     98.000000   68.000000  2346.25000
# max    44.300000   6.000000    146.000000   82.000000  3250.00000
#
#        acceleration      model     origin
# count     24.000000  24.000000  24.000000
# mean      19.941667  78.375000   2.458333
# std        1.670177   3.320719   0.658005
# min       18.200000  71.000000   1.000000
# 25%       18.950000  77.000000   2.000000
# 50%       19.400000  80.000000   3.000000
# 75%       20.775000  81.000000   3.000000
# ...

# %%
plt.hist(final['acceleration'],alpha=0.5)
plt.hist(final['mpg'],alpha=0.5);

# %%
plt.hist(final['weight'],alpha=0.5);

# %% [markdown]
# I found the car that weighs the lightest. Lighter cars go faster, but the downfall is that the faster you go the more likely the car will slip. This would require the driver to be more cautious and focus while driving this specific car.

# %%
print(final[final.weight == final.weight.min()])
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 53  31.0          4            71          65    1773          19.0     71
#
#     origin                  car
# 53       3  toyota corolla 1200

# %% [markdown]
# Here is where I go back on choosing the best everyday car, which is the car with the best mpg and with acceleration taken into account as it allows the car to be a bit safer. The weight of the car also makes it safer as it is above average. This would make the car more stable even if you were to drive your car faster, which as an everyday car would be beneficial. As we are always hurrying to get from here to there on an everyday basis.

# %%
print(final[final.mpg == final.mpg.max()])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 127  44.3          4            90          48    2085          21.7     80
#
#      origin                   car
# 127       2  vw rabbit c (diesel)
